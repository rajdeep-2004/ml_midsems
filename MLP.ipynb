# %% [markdown]
# <a href="https://colab.research.google.com/github/rajdeep-2004/ml_midsems/blob/main/MLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %%
X,y = make_classification(n_samples=100, n_features=10)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(10,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
print(model.evaluate(X_test, y_test))
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - accuracy: 0.4000 - loss: 0.7307 - val_accuracy: 0.5000 - val_loss: 0.6687
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5250 - loss: 0.6970 - val_accuracy: 0.5500 - val_loss: 0.6511
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5750 - loss: 0.6703 - val_accuracy: 0.6500 - val_loss: 0.6319
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6750 - loss: 0.6459 - val_accuracy: 0.7500 - val_loss: 0.6107
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.7125 - loss: 0.6242 - val_accuracy: 0.7500 - val_loss: 0.5935
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8000 - loss: 0.6023 - val_accuracy: 0.7500 - val_loss: 0.5755
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8125 - loss: 0.5844 - val_accuracy: 0.7500 - val_loss: 0.5619
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8500 - loss: 0.5644 - val_accuracy: 0.7500 - val_loss: 0.5460
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8875 - loss: 0.5466 - val_accuracy: 0.7500 - val_loss: 0.5316
# Epoch 10/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9000 - loss: 0.5302 - val_accuracy: 0.7500 - val_loss: 0.5183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7500 - loss: 0.5183
# [0.5183283686637878, 0.75]
