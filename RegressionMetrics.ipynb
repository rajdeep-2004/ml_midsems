# %% [markdown]
# <a href="https://colab.research.google.com/github/rajdeep-2004/ml_midsems/blob/main/RegressionMetrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package in LPA')
# Out:
# Text(0, 0.5, 'Package in LPA')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['package']), df['package'], test_size = 0.2, random_state=2)

X_train.shape, X_test.shape
# Out:
# ((160, 1), (40, 1))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predict = model.predict(X_test)

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, model.predict(X_train), color='red')
plt.xlabel('CGPA')
plt.ylabel('Package in LPA')
# Out:
# Text(0, 0.5, 'Package in LPA')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

r2 = r2_score(y_test, predict)
n = len(y_test) # Number of observations
k = X_test.shape[1] # Number of predictor variables

adjusted_r2 = 1 - (1 - r2) * ((n - 1) / (n - k - 1))

print('MAE: ', mean_absolute_error(y_test, predict))
print('MSE: ', mean_squared_error(y_test, predict))
print('R2 Score: ', r2)
print('Adjusted R2 Score: ', adjusted_r2)
# Out:
# MAE:  0.2884710931878175
# MSE:  0.12129235313495527
# R2 Score:  0.780730147510384
# Adjusted R2 Score:  0.7749598882343415
