# %% [markdown]
# <a href="https://colab.research.google.com/github/rajdeep-2004/ml_midsems/blob/main/NLP__TextPreprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import re

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
text = "The quick brown foxes are running over lazy dogs!"

# %%
# Lowercase
text = text.lower()

# %%
# Remove Punctuation
text = re.sub(r'[^a-z\s]', '', text)

# %%
# Tokenize
tokens = word_tokenize(text)

# %%
# Remove stopwords
stop_words = set(stopwords.words('english'))
tokens = [token for token in tokens if token not in stop_words]

# %%
# Stemming
stemmer = PorterStemmer()
stemmed = [stemmer.stem(token) for token in tokens]
print("Stemmed: ", stemmed)
# Out:
# Stemmed:  ['quick', 'brown', 'fox', 'run', 'lazi', 'dog']

# %%
# Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(token) for token in tokens]
print("Lemmatized: ", lemmatized)
# Out:
# Lemmatized:  ['quick', 'brown', 'fox', 'running', 'lazy', 'dog']
